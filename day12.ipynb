# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'seyilaw1'
)

mycursor = mydb.cursor()
mycursor.execute('SHOW DATABASES')
for x in mycursor:
    print(x)
# Out:
# ('hospitalmanagementsystem',)
# ('hospitalrecordsystem',)
# ('information_schema',)
# ('ministrymanagementsystem',)
# ('mysql',)
# ('nigeriaministrymanagementsystem',)
# ('performance_schema',)
# ('sakila',)
# ('schoolmanagementsystem',)
# ('sys',)
# ('world',)

# %%
mydb = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'seyilaw1',
    database = 'schoolmanagementsystem'
)

mycursor = mydb.cursor()
mycursor.execute('SHOW tables')
for x in mycursor:
    print(x)
# Out:
# ('groupadetails',)
# ('groupbdetails',)
# ('groupcdetails',)
# ('groupddetails',)
# ('groupedetails',)
# ('studentsperformance',)

# %%
mydb = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'seyilaw1',
    database = 'schoolmanagementsystem'
)

mycursor = mydb.cursor()
mycursor.execute('select * from studentsperformance')
for x in mycursor:
    print(x)
# Out:
# (1, 'female', 'group B', "bachelor's degree", 'standard', 'none', 72, 72, 74)
# (2, 'female', 'group C', 'some college', 'standard', 'completed', 69, 90, 88)
# (3, 'female', 'group B', "master's degree", 'standard', 'none', 90, 95, 93)
# (4, 'male', 'group A', "associate's degree", 'free/reduced', 'none', 47, 57, 44)
# (5, 'male', 'group C', 'some college', 'standard', 'none', 76, 78, 75)
# (6, 'female', 'group B', "associate's degree", 'standard', 'none', 71, 83, 78)
# (7, 'female', 'group B', 'some college', 'standard', 'completed', 88, 95, 92)
# (8, 'male', 'group B', 'some college', 'free/reduced', 'none', 40, 43, 39)
# (9, 'male', 'group D', 'high school', 'free/reduced', 'completed', 64, 64, 67)
# (10, 'female', 'group B', 'high school', 'free/reduced', 'none', 38, 60, 50)
# (11, 'male', 'group C', "associate's degree", 'standard', 'none', 58, 54, 52)
# (12, 'male', 'group D', "associate's degree", 'standard', 'none', 40, 52, 43)
# ...

# %%
# write a query command to select those in group C and luch is standard
# write a query command to select records from 50 to 150
# write a query command to check if the column of gender is having a missing value
# write a query command to create the following  tables from studentsperformance
#1. those that  their mathscore is >= 65
#2. those that their lunch is standard
#3. those that their testpreparetion is completed
# Out:
# ('ID', b'int', 'NO', 'PRI', None, 'auto_increment')
# ('gender', b'text', 'YES', '', None, '')
# ('raceethnicity', b'text', 'YES', '', None, '')
# ('parentalevelofeducation', b'text', 'YES', '', None, '')
# ('lunch', b'text', 'YES', '', None, '')
# ('testpreparationcourse', b'text', 'YES', '', None, '')
# ('mathscore', b'int', 'YES', '', None, '')
# ('readingscore', b'int', 'YES', '', None, '')
# ('writingscore', b'int', 'YES', '', None, '')

# %%
mydb = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'seyilaw1',
    database = 'schoolmanagementsystem'
)

mycursor = mydb.cursor()
mycursor.execute("select * from studentsperformance where raceethnicity = 'group C' and lunch = 'standard'")
for x in mycursor:
    print(x)
# Out:
# (2, 'female', 'group C', 'some college', 'standard', 'completed', 69, 90, 88)
# (5, 'male', 'group C', 'some college', 'standard', 'none', 76, 78, 75)
# (11, 'male', 'group C', "associate's degree", 'standard', 'none', 58, 54, 52)
# (16, 'female', 'group C', 'some high school', 'standard', 'none', 69, 75, 78)
# (17, 'male', 'group C', 'high school', 'standard', 'none', 88, 89, 86)
# (24, 'female', 'group C', 'some high school', 'standard', 'none', 69, 73, 73)
# (28, 'female', 'group C', "bachelor's degree", 'standard', 'none', 67, 69, 75)
# (29, 'male', 'group C', 'high school', 'standard', 'none', 70, 70, 65)
# (42, 'female', 'group C', "associate's degree", 'standard', 'none', 58, 73, 68)
# (48, 'female', 'group C', 'high school', 'standard', 'none', 66, 71, 76)
# (50, 'male', 'group C', 'high school', 'standard', 'completed', 82, 84, 82)
# (53, 'male', 'group C', 'some college', 'standard', 'none', 53, 44, 42)
# ...
